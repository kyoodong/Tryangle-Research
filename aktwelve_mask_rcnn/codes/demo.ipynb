# %% [markdown]
# # Mask R-CNN Demo
#
# A quick intro to using the pre-trained model to detect and segment objects.

# %%
import os
import sys
import random
import math
import numpy as np
import skimage.io
import matplotlib
import matplotlib.pyplot as plt
from process import image_api
import cv2

# Root directory of the project
ROOT_DIR = os.path.abspath("../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
# Import COCO config
sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))  # To find local version
import coco

# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# Directory of images to run detection on
IMAGE_DIR = os.path.join(ROOT_DIR, "images")

# %% [markdown]
# ## Configurations
#
# We'll be using a model trained on the MS-COCO dataset. The configurations of this model are in the ```CocoConfig``` class in ```coco.py```.
#
# For inferencing, modify the configurations a bit to fit the task. To do so, sub-class the ```CocoConfig``` class and override the attributes you need to change.

# %%
class InferenceConfig(coco.CocoConfig):
    # Set batch size to 1 since we'll be running inference on
    # one image at a time. Batch size = GPU_COUNT * IMAGES_PER_GPU
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                93
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco
# NUM_CLASSES                    81
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ## Create Model and Load Trained Weights

# %%
# Create model object in inference mode.
model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR, config=config)

# Load weights trained on MS-COCO
model.load_weights(COCO_MODEL_PATH, by_name=True)
# Out:
# WARNING:tensorflow:From /Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py:574: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# 2020-08-15 22:04:00,906 WARNING From /Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py:574: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %% [markdown]
# ## Class Names
#
# The model classifies objects and returns class IDs, which are integer value that identify each class. Some datasets assign integer values to their classes and some don't. For example, in the MS-COCO dataset, the 'person' class is 1 and 'teddy bear' is 88. The IDs are often sequential, but not always. The COCO dataset, for example, has classes associated with class IDs 70 and 72, but not 71.
#
# To improve consistency, and to support training on data from multiple sources at the same time, our ```Dataset``` class assigns it's own sequential integer IDs to each class. For example, if you load the COCO dataset using our ```Dataset``` class, the 'person' class would get class ID = 1 (just like COCO) and the 'teddy bear' class is 78 (different from COCO). Keep that in mind when mapping class IDs to class names.
#
# To get the list of class names, you'd load the dataset and then use the ```class_names``` property like this.
# ```
# # Load COCO dataset
# dataset = coco.CocoDataset()
# dataset.load_coco(COCO_DIR, "train")
# dataset.prepare()
#
# # Print class names
# print(dataset.class_names)
# ```
#
# We don't want to require you to download the COCO dataset just to run this demo, so we're including the list of class names below. The index of the class name in the list represent its ID (first class is 0, second is 1, third is 2, ...etc.)

# %%
# COCO Class names
# Index of the class in the list is its ID. For example, to get ID of
# the teddy bear class, use: class_names.index('teddy bear')
class_names = ['BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
               'bus', 'train', 'truck', 'boat', 'traffic light',
               'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
               'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
               'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
               'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
               'kite', 'baseball bat', 'baseball glove', 'skateboard',
               'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
               'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
               'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
               'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
               'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
               'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
               'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
               'teddy bear', 'hair drier', 'toothbrush']

# %% [markdown]
# ## Run Object Detection

# %%
# Load a random image from the images folder
file_names = next(os.walk(IMAGE_DIR))[2]
# image = skimage.io.imread(os.path.join(IMAGE_DIR, random.choice(file_names)))
image = skimage.io.imread(os.path.join(IMAGE_DIR, "test2.jpg"))

# Run detection
results = model.detect([image], verbose=1)

# Visualize results
r = results[0]

# 외곽선만 따도록 수정
layered_image, center_points = image_api.get_contour_center_point(r['masks'], 0.01)

# for i in range(r['masks'].shape[-1]):
#     plt.imshow(layered_image[:,:, i])
#     plt.show()

all_layered_image = np.zeros([image.shape[0], image.shape[1], 1])
for i in range(layered_image.shape[-1]):
    all_layered_image[:, :, 0] += layered_image[:, :, i]

for index, center_point in enumerate(center_points):
    if center_point:
        all_layered_image = cv2.circle(all_layered_image, center_point, 5, 1, 2)
        print(image_api.recommend_object_position(center_point, image, r['class_ids'][index] == 1))

plt.imshow(all_layered_image, 'gray', vmin=0, vmax=1)
plt.show()
visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                            class_names, r['scores'])
# Out:
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# WARNING:tensorflow:From /Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_v1.py:2070: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# center_point (325, 543)
# image (640, 640, 3)
# is_person True
# input_image
# input_image_meta
# input_anchors
# zero_padding2d/Pad/paddings
# zero_padding2d/Pad
# conv1/kernel/Initializer/random_uniform/shape
# conv1/kernel/Initializer/random_uniform/min
# conv1/kernel/Initializer/random_uniform/max
# conv1/kernel/Initializer/random_uniform/RandomUniform
# conv1/kernel/Initializer/random_uniform/sub
# conv1/kernel/Initializer/random_uniform/mul
# conv1/kernel/Initializer/random_uniform
# conv1/kernel
# conv1/kernel/IsInitialized/VarIsInitializedOp
# conv1/kernel/Assign
# conv1/kernel/Read/ReadVariableOp
# conv1/bias/Initializer/zeros
# conv1/bias
# conv1/bias/IsInitialized/VarIsInitializedOp
# conv1/bias/Assign
# conv1/bias/Read/ReadVariableOp
# conv1/Conv2D/ReadVariableOp
# conv1/Conv2D
# conv1/BiasAdd/ReadVariableOp
# conv1/BiasAdd
# bn_conv1/gamma/Initializer/ones
# bn_conv1/gamma
# bn_conv1/gamma/IsInitialized/VarIsInitializedOp
# bn_conv1/gamma/Assign
# bn_conv1/gamma/Read/ReadVariableOp
# bn_conv1/beta/Initializer/zeros
# bn_conv1/beta
# bn_conv1/beta/IsInitialized/VarIsInitializedOp
# bn_conv1/beta/Assign
# bn_conv1/beta/Read/ReadVariableOp
# bn_conv1/moving_mean/Initializer/zeros
# bn_conv1/moving_mean
# bn_conv1/moving_mean/IsInitialized/VarIsInitializedOp
# bn_conv1/moving_mean/Assign
# bn_conv1/moving_mean/Read/ReadVariableOp
# bn_conv1/moving_variance/Initializer/ones
# bn_conv1/moving_variance
# bn_conv1/moving_variance/IsInitialized/VarIsInitializedOp
# bn_conv1/moving_variance/Assign
# bn_conv1/moving_variance/Read/ReadVariableOp
# bn_conv1/ReadVariableOp
# bn_conv1/ReadVariableOp_1
# bn_conv1/FusedBatchNormV3/ReadVariableOp
# bn_conv1/FusedBatchNormV3/ReadVariableOp_1
# bn_conv1/FusedBatchNormV3
# activation/Relu
# max_pooling2d/MaxPool
# res2a_branch2a/kernel/Initializer/random_uniform/shape
# res2a_branch2a/kernel/Initializer/random_uniform/min
# res2a_branch2a/kernel/Initializer/random_uniform/max
# res2a_branch2a/kernel/Initializer/random_uniform/RandomUniform
# res2a_branch2a/kernel/Initializer/random_uniform/sub
# res2a_branch2a/kernel/Initializer/random_uniform/mul
# res2a_branch2a/kernel/Initializer/random_uniform
# res2a_branch2a/kernel
# res2a_branch2a/kernel/IsInitialized/VarIsInitializedOp
# res2a_branch2a/kernel/Assign
# res2a_branch2a/kernel/Read/ReadVariableOp
# res2a_branch2a/bias/Initializer/zeros
# res2a_branch2a/bias
# res2a_branch2a/bias/IsInitialized/VarIsInitializedOp
# res2a_branch2a/bias/Assign
# res2a_branch2a/bias/Read/ReadVariableOp
# res2a_branch2a/Conv2D/ReadVariableOp
# res2a_branch2a/Conv2D
# res2a_branch2a/BiasAdd/ReadVariableOp
# res2a_branch2a/BiasAdd
# bn2a_branch2a/gamma/Initializer/ones
# bn2a_branch2a/gamma
# bn2a_branch2a/gamma/IsInitialized/VarIsInitializedOp
# bn2a_branch2a/gamma/Assign
# bn2a_branch2a/gamma/Read/ReadVariableOp
# bn2a_branch2a/beta/Initializer/zeros
# bn2a_branch2a/beta
# bn2a_branch2a/beta/IsInitialized/VarIsInitializedOp
# bn2a_branch2a/beta/Assign
# bn2a_branch2a/beta/Read/ReadVariableOp
# bn2a_branch2a/moving_mean/Initializer/zeros
# bn2a_branch2a/moving_mean
# bn2a_branch2a/moving_mean/IsInitialized/VarIsInitializedOp
# bn2a_branch2a/moving_mean/Assign
# bn2a_branch2a/moving_mean/Read/ReadVariableOp
# bn2a_branch2a/moving_variance/Initializer/ones
# bn2a_branch2a/moving_variance
# bn2a_branch2a/moving_variance/IsInitialized/VarIsInitializedOp
# bn2a_branch2a/moving_variance/Assign
# bn2a_branch2a/moving_variance/Read/ReadVariableOp
# bn2a_branch2a/ReadVariableOp
# bn2a_branch2a/ReadVariableOp_1
# bn2a_branch2a/FusedBatchNormV3/ReadVariableOp
# bn2a_branch2a/FusedBatchNormV3/ReadVariableOp_1
# bn2a_branch2a/FusedBatchNormV3
# activation_1/Relu
# res2a_branch2b/kernel/Initializer/random_uniform/shape
# res2a_branch2b/kernel/Initializer/random_uniform/min
# res2a_branch2b/kernel/Initializer/random_uniform/max
# res2a_branch2b/kernel/Initializer/random_uniform/RandomUniform
# res2a_branch2b/kernel/Initializer/random_uniform/sub
# res2a_branch2b/kernel/Initializer/random_uniform/mul
# res2a_branch2b/kernel/Initializer/random_uniform
# res2a_branch2b/kernel
# res2a_branch2b/kernel/IsInitialized/VarIsInitializedOp
# res2a_branch2b/kernel/Assign
# res2a_branch2b/kernel/Read/ReadVariableOp
# res2a_branch2b/bias/Initializer/zeros
# res2a_branch2b/bias
# res2a_branch2b/bias/IsInitialized/VarIsInitializedOp
# res2a_branch2b/bias/Assign
# res2a_branch2b/bias/Read/ReadVariableOp
# res2a_branch2b/Conv2D/ReadVariableOp
# res2a_branch2b/Conv2D
# res2a_branch2b/BiasAdd/ReadVariableOp
# res2a_branch2b/BiasAdd
# bn2a_branch2b/gamma/Initializer/ones
# bn2a_branch2b/gamma
# bn2a_branch2b/gamma/IsInitialized/VarIsInitializedOp
# bn2a_branch2b/gamma/Assign
# bn2a_branch2b/gamma/Read/ReadVariableOp
# bn2a_branch2b/beta/Initializer/zeros
# bn2a_branch2b/beta
# bn2a_branch2b/beta/IsInitialized/VarIsInitializedOp
# bn2a_branch2b/beta/Assign
# bn2a_branch2b/beta/Read/ReadVariableOp
# bn2a_branch2b/moving_mean/Initializer/zeros
# bn2a_branch2b/moving_mean
# bn2a_branch2b/moving_mean/IsInitialized/VarIsInitializedOp
# bn2a_branch2b/moving_mean/Assign
# bn2a_branch2b/moving_mean/Read/ReadVariableOp
# bn2a_branch2b/moving_variance/Initializer/ones
# bn2a_branch2b/moving_variance
# bn2a_branch2b/moving_variance/IsInitialized/VarIsInitializedOp
# bn2a_branch2b/moving_variance/Assign
# bn2a_branch2b/moving_variance/Read/ReadVariableOp
# bn2a_branch2b/ReadVariableOp
# bn2a_branch2b/ReadVariableOp_1
# bn2a_branch2b/FusedBatchNormV3/ReadVariableOp
# bn2a_branch2b/FusedBatchNormV3/ReadVariableOp_1
# bn2a_branch2b/FusedBatchNormV3
# activation_2/Relu
# res2a_branch2c/kernel/Initializer/random_uniform/shape
# res2a_branch2c/kernel/Initializer/random_uniform/min
# res2a_branch2c/kernel/Initializer/random_uniform/max
# res2a_branch2c/kernel/Initializer/random_uniform/RandomUniform
# res2a_branch2c/kernel/Initializer/random_uniform/sub
# res2a_branch2c/kernel/Initializer/random_uniform/mul
# res2a_branch2c/kernel/Initializer/random_uniform
# res2a_branch2c/kernel
# res2a_branch2c/kernel/IsInitialized/VarIsInitializedOp
# res2a_branch2c/kernel/Assign
# res2a_branch2c/kernel/Read/ReadVariableOp
# res2a_branch2c/bias/Initializer/zeros
# res2a_branch2c/bias
# res2a_branch2c/bias/IsInitialized/VarIsInitializedOp
# res2a_branch2c/bias/Assign
# res2a_branch2c/bias/Read/ReadVariableOp
# res2a_branch2c/Conv2D/ReadVariableOp
# res2a_branch2c/Conv2D
# res2a_branch2c/BiasAdd/ReadVariableOp
# res2a_branch2c/BiasAdd
# bn2a_branch2c/gamma/Initializer/ones
# bn2a_branch2c/gamma
# bn2a_branch2c/gamma/IsInitialized/VarIsInitializedOp
# bn2a_branch2c/gamma/Assign
# bn2a_branch2c/gamma/Read/ReadVariableOp
# bn2a_branch2c/beta/Initializer/zeros
# bn2a_branch2c/beta
# bn2a_branch2c/beta/IsInitialized/VarIsInitializedOp
# bn2a_branch2c/beta/Assign
# bn2a_branch2c/beta/Read/ReadVariableOp
# bn2a_branch2c/moving_mean/Initializer/zeros
# bn2a_branch2c/moving_mean
# bn2a_branch2c/moving_mean/IsInitialized/VarIsInitializedOp
# bn2a_branch2c/moving_mean/Assign
# bn2a_branch2c/moving_mean/Read/ReadVariableOp
# bn2a_branch2c/moving_variance/Initializer/ones
# bn2a_branch2c/moving_variance
# bn2a_branch2c/moving_variance/IsInitialized/VarIsInitializedOp
# bn2a_branch2c/moving_variance/Assign
# bn2a_branch2c/moving_variance/Read/ReadVariableOp
# bn2a_branch2c/ReadVariableOp
# bn2a_branch2c/ReadVariableOp_1
# bn2a_branch2c/FusedBatchNormV3/ReadVariableOp
# bn2a_branch2c/FusedBatchNormV3/ReadVariableOp_1
# bn2a_branch2c/FusedBatchNormV3
# res2a_branch1/kernel/Initializer/random_uniform/shape
# res2a_branch1/kernel/Initializer/random_uniform/min
# res2a_branch1/kernel/Initializer/random_uniform/max
# res2a_branch1/kernel/Initializer/random_uniform/RandomUniform
# res2a_branch1/kernel/Initializer/random_uniform/sub
# res2a_branch1/kernel/Initializer/random_uniform/mul
# res2a_branch1/kernel/Initializer/random_uniform
# res2a_branch1/kernel
# res2a_branch1/kernel/IsInitialized/VarIsInitializedOp
# res2a_branch1/kernel/Assign
# res2a_branch1/kernel/Read/ReadVariableOp
# res2a_branch1/bias/Initializer/zeros
# res2a_branch1/bias
# res2a_branch1/bias/IsInitialized/VarIsInitializedOp
# res2a_branch1/bias/Assign
# res2a_branch1/bias/Read/ReadVariableOp
# res2a_branch1/Conv2D/ReadVariableOp
# res2a_branch1/Conv2D
# res2a_branch1/BiasAdd/ReadVariableOp
# res2a_branch1/BiasAdd
# bn2a_branch1/gamma/Initializer/ones
# bn2a_branch1/gamma
# bn2a_branch1/gamma/IsInitialized/VarIsInitializedOp
# bn2a_branch1/gamma/Assign
# bn2a_branch1/gamma/Read/ReadVariableOp
# bn2a_branch1/beta/Initializer/zeros
# bn2a_branch1/beta
# bn2a_branch1/beta/IsInitialized/VarIsInitializedOp
# bn2a_branch1/beta/Assign
# bn2a_branch1/beta/Read/ReadVariableOp
# bn2a_branch1/moving_mean/Initializer/zeros
# bn2a_branch1/moving_mean
# bn2a_branch1/moving_mean/IsInitialized/VarIsInitializedOp
# bn2a_branch1/moving_mean/Assign
# bn2a_branch1/moving_mean/Read/ReadVariableOp
# bn2a_branch1/moving_variance/Initializer/ones
# bn2a_branch1/moving_variance
# bn2a_branch1/moving_variance/IsInitialized/VarIsInitializedOp
# bn2a_branch1/moving_variance/Assign
# bn2a_branch1/moving_variance/Read/ReadVariableOp
# bn2a_branch1/ReadVariableOp
# bn2a_branch1/ReadVariableOp_1
# bn2a_branch1/FusedBatchNormV3/ReadVariableOp
# bn2a_branch1/FusedBatchNormV3/ReadVariableOp_1
# bn2a_branch1/FusedBatchNormV3
# add/add
# res2a_out/Relu
# res2b_branch2a/kernel/Initializer/random_uniform/shape
# res2b_branch2a/kernel/Initializer/random_uniform/min
# res2b_branch2a/kernel/Initializer/random_uniform/max
# res2b_branch2a/kernel/Initializer/random_uniform/RandomUniform
# res2b_branch2a/kernel/Initializer/random_uniform/sub
# res2b_branch2a/kernel/Initializer/random_uniform/mul
# res2b_branch2a/kernel/Initializer/random_uniform
# res2b_branch2a/kernel
# res2b_branch2a/kernel/IsInitialized/VarIsInitializedOp
# res2b_branch2a/kernel/Assign
# res2b_branch2a/kernel/Read/ReadVariableOp
# res2b_branch2a/bias/Initializer/zeros
# res2b_branch2a/bias
# res2b_branch2a/bias/IsInitialized/VarIsInitializedOp
# res2b_branch2a/bias/Assign
# res2b_branch2a/bias/Read/ReadVariableOp
# res2b_branch2a/Conv2D/ReadVariableOp
# res2b_branch2a/Conv2D
# res2b_branch2a/BiasAdd/ReadVariableOp
# res2b_branch2a/BiasAdd
# bn2b_branch2a/gamma/Initializer/ones
# bn2b_branch2a/gamma
# bn2b_branch2a/gamma/IsInitialized/VarIsInitializedOp
# bn2b_branch2a/gamma/Assign
# bn2b_branch2a/gamma/Read/ReadVariableOp
# bn2b_branch2a/beta/Initializer/zeros
# bn2b_branch2a/beta
# bn2b_branch2a/beta/IsInitialized/VarIsInitializedOp
# bn2b_branch2a/beta/Assign
# bn2b_branch2a/beta/Read/ReadVariableOp
# bn2b_branch2a/moving_mean/Initializer/zeros
# bn2b_branch2a/moving_mean
# bn2b_branch2a/moving_mean/IsInitialized/VarIsInitializedOp
# bn2b_branch2a/moving_mean/Assign
# bn2b_branch2a/moving_mean/Read/ReadVariableOp
# bn2b_branch2a/moving_variance/Initializer/ones
# bn2b_branch2a/moving_variance
# bn2b_branch2a/moving_variance/IsInitialized/VarIsInitializedOp
# bn2b_branch2a/moving_variance/Assign
# bn2b_branch2a/moving_variance/Read/ReadVariableOp
# bn2b_branch2a/ReadVariableOp
# bn2b_branch2a/ReadVariableOp_1
# bn2b_branch2a/FusedBatchNormV3/ReadVariableOp
# bn2b_branch2a/FusedBatchNormV3/ReadVariableOp_1
# bn2b_branch2a/FusedBatchNormV3
# activation_3/Relu
# res2b_branch2b/kernel/Initializer/random_uniform/shape
# res2b_branch2b/kernel/Initializer/random_uniform/min
# res2b_branch2b/kernel/Initializer/random_uniform/max
# res2b_branch2b/kernel/Initializer/random_uniform/RandomUniform
# res2b_branch2b/kernel/Initializer/random_uniform/sub
# res2b_branch2b/kernel/Initializer/random_uniform/mul
# res2b_branch2b/kernel/Initializer/random_uniform
# res2b_branch2b/kernel
# res2b_branch2b/kernel/IsInitialized/VarIsInitializedOp
# res2b_branch2b/kernel/Assign
# res2b_branch2b/kernel/Read/ReadVariableOp
# res2b_branch2b/bias/Initializer/zeros
# res2b_branch2b/bias
# res2b_branch2b/bias/IsInitialized/VarIsInitializedOp
# res2b_branch2b/bias/Assign
# res2b_branch2b/bias/Read/ReadVariableOp
# res2b_branch2b/Conv2D/ReadVariableOp
# res2b_branch2b/Conv2D
# res2b_branch2b/BiasAdd/ReadVariableOp
# res2b_branch2b/BiasAdd
# bn2b_branch2b/gamma/Initializer/ones
# bn2b_branch2b/gamma
# bn2b_branch2b/gamma/IsInitialized/VarIsInitializedOp
# bn2b_branch2b/gamma/Assign
# bn2b_branch2b/gamma/Read/ReadVariableOp
# bn2b_branch2b/beta/Initializer/zeros
# bn2b_branch2b/beta
# bn2b_branch2b/beta/IsInitialized/VarIsInitializedOp
# bn2b_branch2b/beta/Assign
# bn2b_branch2b/beta/Read/ReadVariableOp
# bn2b_branch2b/moving_mean/Initializer/zeros
# bn2b_branch2b/moving_mean
# bn2b_branch2b/moving_mean/IsInitialized/VarIsInitializedOp
# bn2b_branch2b/moving_mean/Assign
# bn2b_branch2b/moving_mean/Read/ReadVariableOp
# bn2b_branch2b/moving_variance/Initializer/ones
# bn2b_branch2b/moving_variance
# bn2b_branch2b/moving_variance/IsInitialized/VarIsInitializedOp
# bn2b_branch2b/moving_variance/Assign
# bn2b_branch2b/moving_variance/Read/ReadVariableOp
# bn2b_branch2b/ReadVariableOp
# bn2b_branch2b/ReadVariableOp_1
# bn2b_branch2b/FusedBatchNormV3/ReadVariableOp
# bn2b_branch2b/FusedBatchNormV3/ReadVariableOp_1
# bn2b_branch2b/FusedBatchNormV3
# activation_4/Relu
# res2b_branch2c/kernel/Initializer/random_uniform/shape
# res2b_branch2c/kernel/Initializer/random_uniform/min
# res2b_branch2c/kernel/Initializer/random_uniform/max
# res2b_branch2c/kernel/Initializer/random_uniform/RandomUniform
# res2b_branch2c/kernel/Initializer/random_uniform/sub
# res2b_branch2c/kernel/Initializer/random_uniform/mul
# res2b_branch2c/kernel/Initializer/random_uniform
# res2b_branch2c/kernel
# res2b_branch2c/kernel/IsInitialized/VarIsInitializedOp
# res2b_branch2c/kernel/Assign
# res2b_branch2c/kernel/Read/ReadVariableOp
# res2b_branch2c/bias/Initializer/zeros
# res2b_branch2c/bias
# res2b_branch2c/bias/IsInitialized/VarIsInitializedOp
# res2b_branch2c/bias/Assign
# res2b_branch2c/bias/Read/ReadVariableOp
# res2b_branch2c/Conv2D/ReadVariableOp
# res2b_branch2c/Conv2D
# res2b_branch2c/BiasAdd/ReadVariableOp
# res2b_branch2c/BiasAdd
# bn2b_branch2c/gamma/Initializer/ones
# bn2b_branch2c/gamma
# bn2b_branch2c/gamma/IsInitialized/VarIsInitializedOp
# bn2b_branch2c/gamma/Assign
# bn2b_branch2c/gamma/Read/ReadVariableOp
# bn2b_branch2c/beta/Initializer/zeros
# bn2b_branch2c/beta
# bn2b_branch2c/beta/IsInitialized/VarIsInitializedOp
# bn2b_branch2c/beta/Assign
# bn2b_branch2c/beta/Read/ReadVariableOp
# bn2b_branch2c/moving_mean/Initializer/zeros
# bn2b_branch2c/moving_mean
# bn2b_branch2c/moving_mean/IsInitialized/VarIsInitializedOp
# bn2b_branch2c/moving_mean/Assign
# bn2b_branch2c/moving_mean/Read/ReadVariableOp
# bn2b_branch2c/moving_variance/Initializer/ones
# bn2b_branch2c/moving_variance
# bn2b_branch2c/moving_variance/IsInitialized/VarIsInitializedOp
# bn2b_branch2c/moving_variance/Assign
# bn2b_branch2c/moving_variance/Read/ReadVariableOp
# bn2b_branch2c/ReadVariableOp
# bn2b_branch2c/ReadVariableOp_1
# bn2b_branch2c/FusedBatchNormV3/ReadVariableOp
# bn2b_branch2c/FusedBatchNormV3/ReadVariableOp_1
# bn2b_branch2c/FusedBatchNormV3
# add_1/add
# res2b_out/Relu
# res2c_branch2a/kernel/Initializer/random_uniform/shape
# res2c_branch2a/kernel/Initializer/random_uniform/min
# res2c_branch2a/kernel/Initializer/random_uniform/max
# res2c_branch2a/kernel/Initializer/random_uniform/RandomUniform
# res2c_branch2a/kernel/Initializer/random_uniform/sub
# res2c_branch2a/kernel/Initializer/random_uniform/mul
# res2c_branch2a/kernel/Initializer/random_uniform
# res2c_branch2a/kernel
# res2c_branch2a/kernel/IsInitialized/VarIsInitializedOp
# res2c_branch2a/kernel/Assign
# res2c_branch2a/kernel/Read/ReadVariableOp
# res2c_branch2a/bias/Initializer/zeros
# res2c_branch2a/bias
# res2c_branch2a/bias/IsInitialized/VarIsInitializedOp
# res2c_branch2a/bias/Assign
# res2c_branch2a/bias/Read/ReadVariableOp
# res2c_branch2a/Conv2D/ReadVariableOp
# res2c_branch2a/Conv2D
# res2c_branch2a/BiasAdd/ReadVariableOp
# res2c_branch2a/BiasAdd
# bn2c_branch2a/gamma/Initializer/ones
# bn2c_branch2a/gamma
# bn2c_branch2a/gamma/IsInitialized/VarIsInitializedOp
# bn2c_branch2a/gamma/Assign
# bn2c_branch2a/gamma/Read/ReadVariableOp
# bn2c_branch2a/beta/Initializer/zeros
# bn2c_branch2a/beta
# bn2c_branch2a/beta/IsInitialized/VarIsInitializedOp
# bn2c_branch2a/beta/Assign
# bn2c_branch2a/beta/Read/ReadVariableOp
# bn2c_branch2a/moving_mean/Initializer/zeros
# bn2c_branch2a/moving_mean
# bn2c_branch2a/moving_mean/IsInitialized/VarIsInitializedOp
# bn2c_branch2a/moving_mean/Assign
# bn2c_branch2a/moving_mean/Read/ReadVariableOp
# bn2c_branch2a/moving_variance/Initializer/ones
# bn2c_branch2a/moving_variance
# bn2c_branch2a/moving_variance/IsInitialized/VarIsInitializedOp
# bn2c_branch2a/moving_variance/Assign
# bn2c_branch2a/moving_variance/Read/ReadVariableOp
# bn2c_branch2a/ReadVariableOp
# bn2c_branch2a/ReadVariableOp_1
# bn2c_branch2a/FusedBatchNormV3/ReadVariableOp
# bn2c_branch2a/FusedBatchNormV3/ReadVariableOp_1
# bn2c_branch2a/FusedBatchNormV3
# activation_5/Relu
# res2c_branch2b/kernel/Initializer/random_uniform/shape
# res2c_branch2b/kernel/Initializer/random_uniform/min
# res2c_branch2b/kernel/Initializer/random_uniform/max
# res2c_branch2b/kernel/Initializer/random_uniform/RandomUniform
# res2c_branch2b/kernel/Initializer/random_uniform/sub
# res2c_branch2b/kernel/Initializer/random_uniform/mul
# res2c_branch2b/kernel/Initializer/random_uniform
# res2c_branch2b/kernel
# res2c_branch2b/kernel/IsInitialized/VarIsInitializedOp
# res2c_branch2b/kernel/Assign
# res2c_branch2b/kernel/Read/ReadVariableOp
# res2c_branch2b/bias/Initializer/zeros
# res2c_branch2b/bias
# res2c_branch2b/bias/IsInitialized/VarIsInitializedOp
# res2c_branch2b/bias/Assign
# res2c_branch2b/bias/Read/ReadVariableOp
# res2c_branch2b/Conv2D/ReadVariableOp
# res2c_branch2b/Conv2D
# res2c_branch2b/BiasAdd/ReadVariableOp
# res2c_branch2b/BiasAdd
# bn2c_branch2b/gamma/Initializer/ones
# bn2c_branch2b/gamma
# bn2c_branch2b/gamma/IsInitialized/VarIsInitializedOp
# bn2c_branch2b/gamma/Assign
# bn2c_branch2b/gamma/Read/ReadVariableOp
# bn2c_branch2b/beta/Initializer/zeros
# bn2c_branch2b/beta
# bn2c_branch2b/beta/IsInitialized/VarIsInitializedOp
# bn2c_branch2b/beta/Assign
# bn2c_branch2b/beta/Read/ReadVariableOp
# bn2c_branch2b/moving_mean/Initializer/zeros
# bn2c_branch2b/moving_mean
# bn2c_branch2b/moving_mean/IsInitialized/VarIsInitializedOp
# bn2c_branch2b/moving_mean/Assign
# bn2c_branch2b/moving_mean/Read/ReadVariableOp
# bn2c_branch2b/moving_variance/Initializer/ones
# bn2c_branch2b/moving_variance
# bn2c_branch2b/moving_variance/IsInitialized/VarIsInitializedOp
# bn2c_branch2b/moving_variance/Assign
# bn2c_branch2b/moving_variance/Read/ReadVariableOp
# bn2c_branch2b/ReadVariableOp
# bn2c_branch2b/ReadVariableOp_1
# bn2c_branch2b/FusedBatchNormV3/ReadVariableOp
# bn2c_branch2b/FusedBatchNormV3/ReadVariableOp_1
# bn2c_branch2b/FusedBatchNormV3
# activation_6/Relu
# res2c_branch2c/kernel/Initializer/random_uniform/shape
# res2c_branch2c/kernel/Initializer/random_uniform/min
# res2c_branch2c/kernel/Initializer/random_uniform/max
# res2c_branch2c/kernel/Initializer/random_uniform/RandomUniform
# res2c_branch2c/kernel/Initializer/random_uniform/sub
# res2c_branch2c/kernel/Initializer/random_uniform/mul
# res2c_branch2c/kernel/Initializer/random_uniform
# res2c_branch2c/kernel
# res2c_branch2c/kernel/IsInitialized/VarIsInitializedOp
# res2c_branch2c/kernel/Assign
# res2c_branch2c/kernel/Read/ReadVariableOp
# res2c_branch2c/bias/Initializer/zeros
# res2c_branch2c/bias
# res2c_branch2c/bias/IsInitialized/VarIsInitializedOp
# res2c_branch2c/bias/Assign
# res2c_branch2c/bias/Read/ReadVariableOp
# res2c_branch2c/Conv2D/ReadVariableOp
# res2c_branch2c/Conv2D
# res2c_branch2c/BiasAdd/ReadVariableOp
# res2c_branch2c/BiasAdd
# bn2c_branch2c/gamma/Initializer/ones
# bn2c_branch2c/gamma
# bn2c_branch2c/gamma/IsInitialized/VarIsInitializedOp
# bn2c_branch2c/gamma/Assign
# bn2c_branch2c/gamma/Read/ReadVariableOp
# bn2c_branch2c/beta/Initializer/zeros
# bn2c_branch2c/beta
# bn2c_branch2c/beta/IsInitialized/VarIsInitializedOp
# bn2c_branch2c/beta/Assign
# bn2c_branch2c/beta/Read/ReadVariableOp
# bn2c_branch2c/moving_mean/Initializer/zeros
# bn2c_branch2c/moving_mean
# bn2c_branch2c/moving_mean/IsInitialized/VarIsInitializedOp
# bn2c_branch2c/moving_mean/Assign
# bn2c_branch2c/moving_mean/Read/ReadVariableOp
# bn2c_branch2c/moving_variance/Initializer/ones
# bn2c_branch2c/moving_variance
# bn2c_branch2c/moving_variance/IsInitialized/VarIsInitializedOp
# bn2c_branch2c/moving_variance/Assign
# bn2c_branch2c/moving_variance/Read/ReadVariableOp
# bn2c_branch2c/ReadVariableOp
# bn2c_branch2c/ReadVariableOp_1
# bn2c_branch2c/FusedBatchNormV3/ReadVariableOp
# bn2c_branch2c/FusedBatchNormV3/ReadVariableOp_1
# bn2c_branch2c/FusedBatchNormV3
# add_2/add
# res2c_out/Relu
# res3a_branch2a/kernel/Initializer/random_uniform/shape
# res3a_branch2a/kernel/Initializer/random_uniform/min
# res3a_branch2a/kernel/Initializer/random_uniform/max
# res3a_branch2a/kernel/Initializer/random_uniform/RandomUniform
# res3a_branch2a/kernel/Initializer/random_uniform/sub
# res3a_branch2a/kernel/Initializer/random_uniform/mul
# res3a_branch2a/kernel/Initializer/random_uniform
# res3a_branch2a/kernel
# res3a_branch2a/kernel/IsInitialized/VarIsInitializedOp
# res3a_branch2a/kernel/Assign
# res3a_branch2a/kernel/Read/ReadVariableOp
# res3a_branch2a/bias/Initializer/zeros
# res3a_branch2a/bias
# res3a_branch2a/bias/IsInitialized/VarIsInitializedOp
# res3a_branch2a/bias/Assign
# res3a_branch2a/bias/Read/ReadVariableOp
# res3a_branch2a/Conv2D/ReadVariableOp
# res3a_branch2a/Conv2D
# res3a_branch2a/BiasAdd/ReadVariableOp
# res3a_branch2a/BiasAdd
# bn3a_branch2a/gamma/Initializer/ones
# bn3a_branch2a/gamma
# bn3a_branch2a/gamma/IsInitialized/VarIsInitializedOp
# bn3a_branch2a/gamma/Assign
# bn3a_branch2a/gamma/Read/ReadVariableOp
# bn3a_branch2a/beta/Initializer/zeros
# bn3a_branch2a/beta
# bn3a_branch2a/beta/IsInitialized/VarIsInitializedOp
# bn3a_branch2a/beta/Assign
# bn3a_branch2a/beta/Read/ReadVariableOp
# bn3a_branch2a/moving_mean/Initializer/zeros
# bn3a_branch2a/moving_mean
# bn3a_branch2a/moving_mean/IsInitialized/VarIsInitializedOp
# bn3a_branch2a/moving_mean/Assign
# bn3a_branch2a/moving_mean/Read/ReadVariableOp
# bn3a_branch2a/moving_variance/Initializer/ones
# bn3a_branch2a/moving_variance
# bn3a_branch2a/moving_variance/IsInitialized/VarIsInitializedOp
# bn3a_branch2a/moving_variance/Assign
# bn3a_branch2a/moving_variance/Read/ReadVariableOp
# bn3a_branch2a/ReadVariableOp
# bn3a_branch2a/ReadVariableOp_1
# bn3a_branch2a/FusedBatchNormV3/ReadVariableOp
# bn3a_branch2a/FusedBatchNormV3/ReadVariableOp_1
# bn3a_branch2a/FusedBatchNormV3
# activation_7/Relu
# res3a_branch2b/kernel/Initializer/random_uniform/shape
# res3a_branch2b/kernel/Initializer/random_uniform/min
# res3a_branch2b/kernel/Initializer/random_uniform/max
# res3a_branch2b/kernel/Initializer/random_uniform/RandomUniform
# res3a_branch2b/kernel/Initializer/random_uniform/sub
# res3a_branch2b/kernel/Initializer/random_uniform/mul
# res3a_branch2b/kernel/Initializer/random_uniform
# res3a_branch2b/kernel
# res3a_branch2b/kernel/IsInitialized/VarIsInitializedOp
# res3a_branch2b/kernel/Assign
# res3a_branch2b/kernel/Read/ReadVariableOp
# res3a_branch2b/bias/Initializer/zeros
# res3a_branch2b/bias
# res3a_branch2b/bias/IsInitialized/VarIsInitializedOp
# res3a_branch2b/bias/Assign
# res3a_branch2b/bias/Read/ReadVariableOp
# res3a_branch2b/Conv2D/ReadVariableOp
# res3a_branch2b/Conv2D
# res3a_branch2b/BiasAdd/ReadVariableOp
# res3a_branch2b/BiasAdd
# bn3a_branch2b/gamma/Initializer/ones
# bn3a_branch2b/gamma
# bn3a_branch2b/gamma/IsInitialized/VarIsInitializedOp
# bn3a_branch2b/gamma/Assign
# bn3a_branch2b/gamma/Read/ReadVariableOp
# bn3a_branch2b/beta/Initializer/zeros
# bn3a_branch2b/beta
# bn3a_branch2b/beta/IsInitialized/VarIsInitializedOp
# bn3a_branch2b/beta/Assign
# bn3a_branch2b/beta/Read/ReadVariableOp
# bn3a_branch2b/moving_mean/Initializer/zeros
# bn3a_branch2b/moving_mean
# bn3a_branch2b/moving_mean/IsInitialized/VarIsInitializedOp
# bn3a_branch2b/moving_mean/Assign
# bn3a_branch2b/moving_mean/Read/ReadVariableOp
# bn3a_branch2b/moving_variance/Initializer/ones
# bn3a_branch2b/moving_variance
# bn3a_branch2b/moving_variance/IsInitialized/VarIsInitializedOp
# bn3a_branch2b/moving_variance/Assign
# bn3a_branch2b/moving_variance/Read/ReadVariableOp
# bn3a_branch2b/ReadVariableOp
# bn3a_branch2b/ReadVariableOp_1
# bn3a_branch2b/FusedBatchNormV3/ReadVariableOp
# bn3a_branch2b/FusedBatchNormV3/ReadVariableOp_1
# bn3a_branch2b/FusedBatchNormV3
# activation_8/Relu
# res3a_branch2c/kernel/Initializer/random_uniform/shape
# res3a_branch2c/kernel/Initializer/random_uniform/min
# res3a_branch2c/kernel/Initializer/random_uniform/max
# res3a_branch2c/kernel/Initializer/random_uniform/RandomUniform
# res3a_branch2c/kernel/Initializer/random_uniform/sub
# res3a_branch2c/kernel/Initializer/random_uniform/mul
# res3a_branch2c/kernel/Initializer/random_uniform
# res3a_branch2c/kernel
# res3a_branch2c/kernel/IsInitialized/VarIsInitializedOp
# res3a_branch2c/kernel/Assign
# res3a_branch2c/kernel/Read/ReadVariableOp
# res3a_branch2c/bias/Initializer/zeros
# res3a_branch2c/bias
# res3a_branch2c/bias/IsInitialized/VarIsInitializedOp
# res3a_branch2c/bias/Assign
# res3a_branch2c/bias/Read/ReadVariableOp
# res3a_branch2c/Conv2D/ReadVariableOp
# res3a_branch2c/Conv2D
# res3a_branch2c/BiasAdd/ReadVariableOp
# res3a_branch2c/BiasAdd
# bn3a_branch2c/gamma/Initializer/ones
# bn3a_branch2c/gamma
# bn3a_branch2c/gamma/IsInitialized/VarIsInitializedOp
# bn3a_branch2c/gamma/Assign
# bn3a_branch2c/gamma/Read/ReadVariableOp
# bn3a_branch2c/beta/Initializer/zeros
# bn3a_branch2c/beta
# bn3a_branch2c/beta/IsInitialized/VarIsInitializedOp
# bn3a_branch2c/beta/Assign
# bn3a_branch2c/beta/Read/ReadVariableOp
# bn3a_branch2c/moving_mean/Initializer/zeros
# bn3a_branch2c/moving_mean
# bn3a_branch2c/moving_mean/IsInitialized/VarIsInitializedOp
# bn3a_branch2c/moving_mean/Assign
# bn3a_branch2c/moving_mean/Read/ReadVariableOp
# bn3a_branch2c/moving_variance/Initializer/ones
# bn3a_branch2c/moving_variance
# bn3a_branch2c/moving_variance/IsInitialized/VarIsInitializedOp
# bn3a_branch2c/moving_variance/Assign
# bn3a_branch2c/moving_variance/Read/ReadVariableOp
# bn3a_branch2c/ReadVariableOp
# bn3a_branch2c/ReadVariableOp_1
# bn3a_branch2c/FusedBatchNormV3/ReadVariableOp
# bn3a_branch2c/FusedBatchNormV3/ReadVariableOp_1
# bn3a_branch2c/FusedBatchNormV3
# res3a_branch1/kernel/Initializer/random_uniform/shape
# res3a_branch1/kernel/Initializer/random_uniform/min
# res3a_branch1/kernel/Initializer/random_uniform/max
# res3a_branch1/kernel/Initializer/random_uniform/RandomUniform
# res3a_branch1/kernel/Initializer/random_uniform/sub
# res3a_branch1/kernel/Initializer/random_uniform/mul
# res3a_branch1/kernel/Initializer/random_uniform
# res3a_branch1/kernel
# res3a_branch1/kernel/IsInitialized/VarIsInitializedOp
# res3a_branch1/kernel/Assign
# res3a_branch1/kernel/Read/ReadVariableOp
# res3a_branch1/bias/Initializer/zeros
# res3a_branch1/bias
# res3a_branch1/bias/IsInitialized/VarIsInitializedOp
# res3a_branch1/bias/Assign
# res3a_branch1/bias/Read/ReadVariableOp
# res3a_branch1/Conv2D/ReadVariableOp
# res3a_branch1/Conv2D
# res3a_branch1/BiasAdd/ReadVariableOp
# res3a_branch1/BiasAdd
# bn3a_branch1/gamma/Initializer/ones
# bn3a_branch1/gamma
# bn3a_branch1/gamma/IsInitialized/VarIsInitializedOp
# bn3a_branch1/gamma/Assign
# bn3a_branch1/gamma/Read/ReadVariableOp
# bn3a_branch1/beta/Initializer/zeros
# bn3a_branch1/beta
# bn3a_branch1/beta/IsInitialized/VarIsInitializedOp
# bn3a_branch1/beta/Assign
# bn3a_branch1/beta/Read/ReadVariableOp
# bn3a_branch1/moving_mean/Initializer/zeros
# bn3a_branch1/moving_mean
# bn3a_branch1/moving_mean/IsInitialized/VarIsInitializedOp
# bn3a_branch1/moving_mean/Assign
# bn3a_branch1/moving_mean/Read/ReadVariableOp
# bn3a_branch1/moving_variance/Initializer/ones
# bn3a_branch1/moving_variance
# bn3a_branch1/moving_variance/IsInitialized/VarIsInitializedOp
# bn3a_branch1/moving_variance/Assign
# bn3a_branch1/moving_variance/Read/ReadVariableOp
# bn3a_branch1/ReadVariableOp
# bn3a_branch1/ReadVariableOp_1
# bn3a_branch1/FusedBatchNormV3/ReadVariableOp
# bn3a_branch1/FusedBatchNormV3/ReadVariableOp_1
# bn3a_branch1/FusedBatchNormV3
# add_3/add
# res3a_out/Relu
# res3b_branch2a/kernel/Initializer/random_uniform/shape
# res3b_branch2a/kernel/Initializer/random_uniform/min
# res3b_branch2a/kernel/Initializer/random_uniform/max
# res3b_branch2a/kernel/Initializer/random_uniform/RandomUniform
# res3b_branch2a/kernel/Initializer/random_uniform/sub
# res3b_branch2a/kernel/Initializer/random_uniform/mul
# res3b_branch2a/kernel/Initializer/random_uniform
# res3b_branch2a/kernel
# res3b_branch2a/kernel/IsInitialized/VarIsInitializedOp
# res3b_branch2a/kernel/Assign
# res3b_branch2a/kernel/Read/ReadVariableOp
# res3b_branch2a/bias/Initializer/zeros
# res3b_branch2a/bias
# res3b_branch2a/bias/IsInitialized/VarIsInitializedOp
# res3b_branch2a/bias/Assign
# res3b_branch2a/bias/Read/ReadVariableOp
# res3b_branch2a/Conv2D/ReadVariableOp
# res3b_branch2a/Conv2D
# res3b_branch2a/BiasAdd/ReadVariableOp
# res3b_branch2a/BiasAdd
# bn3b_branch2a/gamma/Initializer/ones
# bn3b_branch2a/gamma
# bn3b_branch2a/gamma/IsInitialized/VarIsInitializedOp
# bn3b_branch2a/gamma/Assign
# bn3b_branch2a/gamma/Read/ReadVariableOp
# bn3b_branch2a/beta/Initializer/zeros
# bn3b_branch2a/beta
# bn3b_branch2a/beta/IsInitialized/VarIsInitializedOp
# bn3b_branch2a/beta/Assign
# bn3b_branch2a/beta/Read/ReadVariableOp
# bn3b_branch2a/moving_mean/Initializer/zeros
# bn3b_branch2a/moving_mean
# bn3b_branch2a/moving_mean/IsInitialized/VarIsInitializedOp
# bn3b_branch2a/moving_mean/Assign
# bn3b_branch2a/moving_mean/Read/ReadVariableOp
# bn3b_branch2a/moving_variance/Initializer/ones
# bn3b_branch2a/moving_variance
# bn3b_branch2a/moving_variance/IsInitialized/VarIsInitializedOp
# bn3b_branch2a/moving_variance/Assign
# bn3b_branch2a/moving_variance/Read/ReadVariableOp
# bn3b_branch2a/ReadVariableOp
# bn3b_branch2a/ReadVariableOp_1
# bn3b_branch2a/FusedBatchNormV3/ReadVariableOp
# bn3b_branch2a/FusedBatchNormV3/ReadVariableOp_1
# bn3b_branch2a/FusedBatchNormV3
# activation_9/Relu
# res3b_branch2b/kernel/Initializer/random_uniform/shape
# res3b_branch2b/kernel/Initializer/random_uniform/min
# res3b_branch2b/kernel/Initializer/random_uniform/max
# res3b_branch2b/kernel/Initializer/random_uniform/RandomUniform
# res3b_branch2b/kernel/Initializer/random_uniform/sub
# res3b_branch2b/kernel/Initializer/random_uniform/mul
# res3b_branch2b/kernel/Initializer/random_uniform
# res3b_branch2b/kernel
# res3b_branch2b/kernel/IsInitialized/VarIsInitializedOp
# res3b_branch2b/kernel/Assign
# res3b_branch2b/kernel/Read/ReadVariableOp
# res3b_branch2b/bias/Initializer/zeros
# res3b_branch2b/bias
# res3b_branch2b/bias/IsInitialized/VarIsInitializedOp
# res3b_branch2b/bias/Assign
# res3b_branch2b/bias/Read/ReadVariableOp
# res3b_branch2b/Conv2D/ReadVariableOp
# res3b_branch2b/Conv2D
# res3b_branch2b/BiasAdd/ReadVariableOp
# res3b_branch2b/BiasAdd
# bn3b_branch2b/gamma/Initializer/ones
# bn3b_branch2b/gamma
# bn3b_branch2b/gamma/IsInitialized/VarIsInitializedOp
# bn3b_branch2b/gamma/Assign
# bn3b_branch2b/gamma/Read/ReadVariableOp
# bn3b_branch2b/beta/Initializer/zeros
# bn3b_branch2b/beta
# bn3b_branch2b/beta/IsInitialized/VarIsInitializedOp
# bn3b_branch2b/beta/Assign
# bn3b_branch2b/beta/Read/ReadVariableOp
# bn3b_branch2b/moving_mean/Initializer/zeros
# bn3b_branch2b/moving_mean
# bn3b_branch2b/moving_mean/IsInitialized/VarIsInitializedOp
# bn3b_branch2b/moving_mean/Assign
# bn3b_branch2b/moving_mean/Read/ReadVariableOp
# bn3b_branch2b/moving_variance/Initializer/ones
# bn3b_branch2b/moving_variance
# bn3b_branch2b/moving_variance/IsInitialized/VarIsInitializedOp
# bn3b_branch2b/moving_variance/Assign
# bn3b_branch2b/moving_variance/Read/ReadVariableOp
# bn3b_branch2b/ReadVariableOp
# bn3b_branch2b/ReadVariableOp_1
# bn3b_branch2b/FusedBatchNormV3/ReadVariableOp
# bn3b_branch2b/FusedBatchNormV3/ReadVariableOp_1
# bn3b_branch2b/FusedBatchNormV3
# activation_10/Relu
# res3b_branch2c/kernel/Initializer/random_uniform/shape
# res3b_branch2c/kernel/Initializer/random_uniform/min
# res3b_branch2c/kernel/Initializer/random_uniform/max
# res3b_branch2c/kernel/Initializer/random_uniform/RandomUniform
# res3b_branch2c/kernel/Initializer/random_uniform/sub
# res3b_branch2c/kernel/Initializer/random_uniform/mul
# res3b_branch2c/kernel/Initializer/random_uniform
# res3b_branch2c/kernel
# res3b_branch2c/kernel/IsInitialized/VarIsInitializedOp
# res3b_branch2c/kernel/Assign
# res3b_branch2c/kernel/Read/ReadVariableOp
# res3b_branch2c/bias/Initializer/zeros
# res3b_branch2c/bias
# res3b_branch2c/bias/IsInitialized/VarIsInitializedOp
# res3b_branch2c/bias/Assign
# res3b_branch2c/bias/Read/ReadVariableOp
# res3b_branch2c/Conv2D/ReadVariableOp
# res3b_branch2c/Conv2D
# res3b_branch2c/BiasAdd/ReadVariableOp
# res3b_branch2c/BiasAdd
# bn3b_branch2c/gamma/Initializer/ones
# bn3b_branch2c/gamma
# bn3b_branch2c/gamma/IsInitialized/VarIsInitializedOp
# bn3b_branch2c/gamma/Assign
# bn3b_branch2c/gamma/Read/ReadVariableOp
# bn3b_branch2c/beta/Initializer/zeros
# bn3b_branch2c/beta
# bn3b_branch2c/beta/IsInitialized/VarIsInitializedOp
# bn3b_branch2c/beta/Assign
# bn3b_branch2c/beta/Read/ReadVariableOp
# bn3b_branch2c/moving_mean/Initializer/zeros
# bn3b_branch2c/moving_mean
# bn3b_branch2c/moving_mean/IsInitialized/VarIsInitializedOp
# bn3b_branch2c/moving_mean/Assign
# bn3b_branch2c/moving_mean/Read/ReadVariableOp
# bn3b_branch2c/moving_variance/Initializer/ones
# bn3b_branch2c/moving_variance
# bn3b_branch2c/moving_variance/IsInitialized/VarIsInitializedOp
# bn3b_branch2c/moving_variance/Assign
# bn3b_branch2c/moving_variance/Read/ReadVariableOp
# bn3b_branch2c/ReadVariableOp
# bn3b_branch2c/ReadVariableOp_1
# bn3b_branch2c/FusedBatchNormV3/ReadVariableOp
# bn3b_branch2c/FusedBatchNormV3/ReadVariableOp_1
# bn3b_branch2c/FusedBatchNormV3
# add_4/add
# res3b_out/Relu
# res3c_branch2a/kernel/Initializer/random_uniform/shape
# res3c_branch2a/kernel/Initializer/random_uniform/min
# res3c_branch2a/kernel/Initializer/random_uniform/max
# res3c_branch2a/kernel/Initializer/random_uniform/RandomUniform
# res3c_branch2a/kernel/Initializer/random_uniform/sub
# res3c_branch2a/kernel/Initializer/random_uniform/mul
# res3c_branch2a/kernel/Initializer/random_uniform
# res3c_branch2a/kernel
# res3c_branch2a/kernel/IsInitialized/VarIsInitializedOp
# res3c_branch2a/kernel/Assign
# res3c_branch2a/kernel/Read/ReadVariableOp
# res3c_branch2a/bias/Initializer/zeros
# res3c_branch2a/bias
# res3c_branch2a/bias/IsInitialized/VarIsInitializedOp
# res3c_branch2a/bias/Assign
# res3c_branch2a/bias/Read/ReadVariableOp
# res3c_branch2a/Conv2D/ReadVariableOp
# res3c_branch2a/Conv2D
# res3c_branch2a/BiasAdd/ReadVariableOp
# res3c_branch2a/BiasAdd
# bn3c_branch2a/gamma/Initializer/ones
# bn3c_branch2a/gamma
# bn3c_branch2a/gamma/IsInitialized/VarIsInitializedOp
# bn3c_branch2a/gamma/Assign
# bn3c_branch2a/gamma/Read/ReadVariableOp
# bn3c_branch2a/beta/Initializer/zeros
# bn3c_branch2a/beta
# bn3c_branch2a/beta/IsInitialized/VarIsInitializedOp
# bn3c_branch2a/beta/Assign
# bn3c_branch2a/beta/Read/ReadVariableOp
# bn3c_branch2a/moving_mean/Initializer/zeros
# bn3c_branch2a/moving_mean
# bn3c_branch2a/moving_mean/IsInitialized/VarIsInitializedOp
# bn3c_branch2a/moving_mean/Assign
# bn3c_branch2a/moving_mean/Read/ReadVariableOp
# bn3c_branch2a/moving_variance/Initializer/ones
# bn3c_branch2a/moving_variance
# bn3c_branch2a/moving_variance/IsInitialized/VarIsInitializedOp
# bn3c_branch2a/moving_variance/Assign
# bn3c_branch2a/moving_variance/Read/ReadVariableOp
# bn3c_branch2a/ReadVariableOp
# bn3c_branch2a/ReadVariableOp_1
# bn3c_branch2a/FusedBatchNormV3/ReadVariableOp
# bn3c_branch2a/FusedBatchNormV3/ReadVariableOp_1
# bn3c_branch2a/FusedBatchNormV3
# activation_11/Relu
# res3c_branch2b/kernel/Initializer/random_uniform/shape
# res3c_branch2b/kernel/Initializer/random_uniform/min
# res3c_branch2b/kernel/Initializer/random_uniform/max
# res3c_branch2b/kernel/Initializer/random_uniform/RandomUniform
# res3c_branch2b/kernel/Initializer/random_uniform/sub
# res3c_branch2b/kernel/Initializer/random_uniform/mul
# res3c_branch2b/kernel/Initializer/random_uniform
# res3c_branch2b/kernel
# res3c_branch2b/kernel/IsInitialized/VarIsInitializedOp
# res3c_branch2b/kernel/Assign
# res3c_branch2b/kernel/Read/ReadVariableOp
# res3c_branch2b/bias/Initializer/zeros
# res3c_branch2b/bias
# res3c_branch2b/bias/IsInitialized/VarIsInitializedOp
# res3c_branch2b/bias/Assign
# res3c_branch2b/bias/Read/ReadVariableOp
# res3c_branch2b/Conv2D/ReadVariableOp
# res3c_branch2b/Conv2D
# res3c_branch2b/BiasAdd/ReadVariableOp
# res3c_branch2b/BiasAdd
# bn3c_branch2b/gamma/Initializer/ones
# bn3c_branch2b/gamma
# bn3c_branch2b/gamma/IsInitialized/VarIsInitializedOp
# bn3c_branch2b/gamma/Assign
# bn3c_branch2b/gamma/Read/ReadVariableOp
# bn3c_branch2b/beta/Initializer/zeros
# bn3c_branch2b/beta
# bn3c_branch2b/beta/IsInitialized/VarIsInitializedOp
# bn3c_branch2b/beta/Assign
# bn3c_branch2b/beta/Read/ReadVariableOp
# bn3c_branch2b/moving_mean/Initializer/zeros
# bn3c_branch2b/moving_mean
# bn3c_branch2b/moving_mean/IsInitialized/VarIsInitializedOp
# bn3c_branch2b/moving_mean/Assign
# bn3c_branch2b/moving_mean/Read/ReadVariableOp
# bn3c_branch2b/moving_variance/Initializer/ones
# bn3c_branch2b/moving_variance
# bn3c_branch2b/moving_variance/IsInitialized/VarIsInitializedOp
# bn3c_branch2b/moving_variance/Assign
# bn3c_branch2b/moving_variance/Read/ReadVariableOp
# bn3c_branch2b/ReadVariableOp
# bn3c_branch2b/ReadVariableOp_1
# bn3c_branch2b/FusedBatchNormV3/ReadVariableOp
# bn3c_branch2b/FusedBatchNormV3/ReadVariableOp_1
# bn3c_branch2b/FusedBatchNormV3
# activation_12/Relu
# res3c_branch2c/kernel/Initializer/random_uniform/shape
# res3c_branch2c/kernel/Initializer/random_uniform/min
# res3c_branch2c/kernel/Initializer/random_uniform/max
# res3c_branch2c/kernel/Initializer/random_uniform/RandomUniform
# res3c_branch2c/kernel/Initializer/random_uniform/sub
# res3c_branch2c/kernel/Initializer/random_uniform/mul
# res3c_branch2c/kernel/Initializer/random_uniform
# res3c_branch2c/kernel
# res3c_branch2c/kernel/IsInitialized/VarIsInitializedOp
# res3c_branch2c/kernel/Assign
# res3c_branch2c/kernel/Read/ReadVariableOp
# res3c_branch2c/bias/Initializer/zeros
# res3c_branch2c/bias
# res3c_branch2c/bias/IsInitialized/VarIsInitializedOp
# res3c_branch2c/bias/Assign
# res3c_branch2c/bias/Read/ReadVariableOp
# res3c_branch2c/Conv2D/ReadVariableOp
# res3c_branch2c/Conv2D
# res3c_branch2c/BiasAdd/ReadVariableOp
# res3c_branch2c/BiasAdd
# bn3c_branch2c/gamma/Initializer/ones
# bn3c_branch2c/gamma
# bn3c_branch2c/gamma/IsInitialized/VarIsInitializedOp
# bn3c_branch2c/gamma/Assign
# bn3c_branch2c/gamma/Read/ReadVariableOp
# bn3c_branch2c/beta/Initializer/zeros
# bn3c_branch2c/beta
# bn3c_branch2c/beta/IsInitialized/VarIsInitializedOp
# bn3c_branch2c/beta/Assign
# bn3c_branch2c/beta/Read/ReadVariableOp
# bn3c_branch2c/moving_mean/Initializer/zeros
# bn3c_branch2c/moving_mean
# bn3c_branch2c/moving_mean/IsInitialized/VarIsInitializedOp
# bn3c_branch2c/moving_mean/Assign
# bn3c_branch2c/moving_mean/Read/ReadVariableOp
# bn3c_branch2c/moving_variance/Initializer/ones
# bn3c_branch2c/moving_variance
# bn3c_branch2c/moving_variance/IsInitialized/VarIsInitializedOp
# bn3c_branch2c/moving_variance/Assign
# bn3c_branch2c/moving_variance/Read/ReadVariableOp
# bn3c_branch2c/ReadVariableOp
# bn3c_branch2c/ReadVariableOp_1
# bn3c_branch2c/FusedBatchNormV3/ReadVariableOp
# bn3c_branch2c/FusedBatchNormV3/ReadVariableOp_1
# bn3c_branch2c/FusedBatchNormV3
# add_5/add
# res3c_out/Relu
# res3d_branch2a/kernel/Initializer/random_uniform/shape
# res3d_branch2a/kernel/Initializer/random_uniform/min
# res3d_branch2a/kernel/Initializer/random_uniform/max
# res3d_branch2a/kernel/Initializer/random_uniform/RandomUniform
# res3d_branch2a/kernel/Initializer/random_uniform/sub
# res3d_branch2a/kernel/Initializer/random_uniform/mul
# res3d_branch2a/kernel/Initializer/random_uniform
# res3d_branch2a/kernel
# res3d_branch2a/kernel/IsInitialized/VarIsInitializedOp
# res3d_branch2a/kernel/Assign
# res3d_branch2a/kernel/Read/ReadVariableOp
# res3d_branch2a/bias/Initializer/zeros
# res3d_branch2a/bias
# res3d_branch2a/bias/IsInitialized/VarIsInitializedOp
# res3d_branch2a/bias/Assign
# res3d_branch2a/bias/Read/ReadVariableOp
# res3d_branch2a/Conv2D/ReadVariableOp
# res3d_branch2a/Conv2D
# res3d_branch2a/BiasAdd/ReadVariableOp
# res3d_branch2a/BiasAdd
# bn3d_branch2a/gamma/Initializer/ones
# bn3d_branch2a/gamma
# bn3d_branch2a/gamma/IsInitialized/VarIsInitializedOp
# bn3d_branch2a/gamma/Assign
# bn3d_branch2a/gamma/Read/ReadVariableOp
# bn3d_branch2a/beta/Initializer/zeros
# bn3d_branch2a/beta
# bn3d_branch2a/beta/IsInitialized/VarIsInitializedOp
# bn3d_branch2a/beta/Assign
# bn3d_branch2a/beta/Read/ReadVariableOp
# bn3d_branch2a/moving_mean/Initializer/zeros
# bn3d_branch2a/moving_mean
# bn3d_branch2a/moving_mean/IsInitialized/VarIsInitializedOp
# bn3d_branch2a/moving_mean/Assign
# bn3d_branch2a/moving_mean/Read/ReadVariableOp
# bn3d_branch2a/moving_variance/Initializer/ones
# bn3d_branch2a/moving_variance
# bn3d_branch2a/moving_variance/IsInitialized/VarIsInitializedOp
# bn3d_branch2a/moving_variance/Assign
# bn3d_branch2a/moving_variance/Read/ReadVariableOp
# bn3d_branch2a/ReadVariableOp
# bn3d_branch2a/ReadVariableOp_1
# bn3d_branch2a/FusedBatchNormV3/ReadVariableOp
# bn3d_branch2a/FusedBatchNormV3/ReadVariableOp_1
# bn3d_branch2a/FusedBatchNormV3
# activation_13/Relu
# res3d_branch2b/kernel/Initializer/random_uniform/shape
# res3d_branch2b/kernel/Initializer/random_uniform/min
# res3d_branch2b/kernel/Initializer/random_uniform/max
# res3d_branch2b/kernel/Initializer/random_uniform/RandomUniform
# res3d_branch2b/kernel/Initializer/random_uniform/sub
# res3d_branch2b/kernel/Initializer/random_uniform/mul
# res3d_branch2b/kernel/Initializer/random_uniform
# res3d_branch2b/kernel
# res3d_branch2b/kernel/IsInitialized/VarIsInitializedOp
# res3d_branch2b/kernel/Assign
# res3d_branch2b/kernel/Read/ReadVariableOp
# res3d_branch2b/bias/Initializer/zeros
# res3d_branch2b/bias
# res3d_branch2b/bias/IsInitialized/VarIsInitializedOp
# res3d_branch2b/bias/Assign
# res3d_branch2b/bias/Read/ReadVariableOp
# res3d_branch2b/Conv2D/ReadVariableOp
# res3d_branch2b/Conv2D
# res3d_branch2b/BiasAdd/ReadVariableOp
# res3d_branch2b/BiasAdd
# bn3d_branch2b/gamma/Initializer/ones
# bn3d_branch2b/gamma
# bn3d_branch2b/gamma/IsInitialized/VarIsInitializedOp
# bn3d_branch2b/gamma/Assign
# bn3d_branch2b/gamma/Read/ReadVariableOp
# bn3d_branch2b/beta/Initializer/zeros
# bn3d_branch2b/beta
# bn3d_branch2b/beta/IsInitialized/VarIsInitializedOp
# bn3d_branch2b/beta/Assign
# bn3d_branch2b/beta/Read/ReadVariableOp
# bn3d_branch2b/moving_mean/Initializer/zeros
# bn3d_branch2b/moving_mean
# bn3d_branch2b/moving_mean/IsInitialized/VarIsInitializedOp
# bn3d_branch2b/moving_mean/Assign
# bn3d_branch2b/moving_mean/Read/ReadVariableOp
# bn3d_branch2b/moving_variance/Initializer/ones
# bn3d_branch2b/moving_variance
# bn3d_branch2b/moving_variance/IsInitialized/VarIsInitializedOp
# bn3d_branch2b/moving_variance/Assign
# bn3d_branch2b/moving_variance/Read/ReadVariableOp
# bn3d_branch2b/ReadVariableOp
# bn3d_branch2b/ReadVariableOp_1
# bn3d_branch2b/FusedBatchNormV3/ReadVariableOp
# bn3d_branch2b/FusedBatchNormV3/ReadVariableOp_1
# bn3d_branch2b/FusedBatchNormV3
# activation_14/Relu
# res3d_branch2c/kernel/Initializer/random_uniform/shape
# res3d_branch2c/kernel/Initializer/random_uniform/min
# res3d_branch2c/kernel/Initializer/random_uniform/max
# res3d_branch2c/kernel/Initializer/random_uniform/RandomUniform
# res3d_branch2c/kernel/Initializer/random_uniform/sub
# res3d_branch2c/kernel/Initializer/random_uniform/mul
# res3d_branch2c/kernel/Initializer/random_uniform
# res3d_branch2c/kernel
# res3d_branch2c/kernel/IsInitialized/VarIsInitializedOp
# res3d_branch2c/kernel/Assign
# res3d_branch2c/kernel/Read/ReadVariableOp
# res3d_branch2c/bias/Initializer/zeros
# res3d_branch2c/bias
# res3d_branch2c/bias/IsInitialized/VarIsInitializedOp
# res3d_branch2c/bias/Assign
# res3d_branch2c/bias/Read/ReadVariableOp
# res3d_branch2c/Conv2D/ReadVariableOp
# res3d_branch2c/Conv2D
# res3d_branch2c/BiasAdd/ReadVariableOp
# res3d_branch2c/BiasAdd
# bn3d_branch2c/gamma/Initializer/ones
# bn3d_branch2c/gamma
# bn3d_branch2c/gamma/IsInitialized/VarIsInitializedOp
# bn3d_branch2c/gamma/Assign
# bn3d_branch2c/gamma/Read/ReadVariableOp
# bn3d_branch2c/beta/Initializer/zeros
# bn3d_branch2c/beta
# bn3d_branch2c/beta/IsInitialized/VarIsInitializedOp
# bn3d_branch2c/beta/Assign
# bn3d_branch2c/beta/Read/ReadVariableOp
# bn3d_branch2c/moving_mean/Initializer/zeros
# bn3d_branch2c/moving_mean
# bn3d_branch2c/moving_mean/IsInitialized/VarIsInitializedOp
# bn3d_branch2c/moving_mean/Assign
# bn3d_branch2c/moving_mean/Read/ReadVariableOp
# bn3d_branch2c/moving_variance/Initializer/ones
# bn3d_branch2c/moving_variance
# bn3d_branch2c/moving_variance/IsInitialized/VarIsInitializedOp
# bn3d_branch2c/moving_variance/Assign
# bn3d_branch2c/moving_variance/Read/ReadVariableOp
# bn3d_branch2c/ReadVariableOp
# bn3d_branch2c/ReadVariableOp_1
# bn3d_branch2c/FusedBatchNormV3/ReadVariableOp
# bn3d_branch2c/FusedBatchNormV3/ReadVariableOp_1
# bn3d_branch2c/FusedBatchNormV3
# add_6/add
# res3d_out/Relu
# res4a_branch2a/kernel/Initializer/random_uniform/shape
# res4a_branch2a/kernel/Initializer/random_uniform/min
# res4a_branch2a/kernel/Initializer/random_uniform/max
# res4a_branch2a/kernel/Initializer/random_uniform/RandomUniform
# res4a_branch2a/kernel/Initializer/random_uniform/sub
# res4a_branch2a/kernel/Initializer/random_uniform/mul
# res4a_branch2a/kernel/Initializer/random_uniform
# res4a_branch2a/kernel
# res4a_branch2a/kernel/IsInitialized/VarIsInitializedOp
# res4a_branch2a/kernel/Assign
# res4a_branch2a/kernel/Read/ReadVariableOp
# res4a_branch2a/bias/Initializer/zeros
# res4a_branch2a/bias
# res4a_branch2a/bias/IsInitialized/VarIsInitializedOp
# res4a_branch2a/bias/Assign
# res4a_branch2a/bias/Read/ReadVariableOp
# res4a_branch2a/Conv2D/ReadVariableOp
# res4a_branch2a/Conv2D
# res4a_branch2a/BiasAdd/ReadVariableOp
# res4a_branch2a/BiasAdd
# bn4a_branch2a/gamma/Initializer/ones
# bn4a_branch2a/gamma
# bn4a_branch2a/gamma/IsInitialized/VarIsInitializedOp
# bn4a_branch2a/gamma/Assign
# bn4a_branch2a/gamma/Read/ReadVariableOp
# bn4a_branch2a/beta/Initializer/zeros
# bn4a_branch2a/beta
# bn4a_branch2a/beta/IsInitialized/VarIsInitializedOp
# bn4a_branch2a/beta/Assign
# bn4a_branch2a/beta/Read/ReadVariableOp
# bn4a_branch2a/moving_mean/Initializer/zeros
# bn4a_branch2a/moving_mean
# bn4a_branch2a/moving_mean/IsInitialized/VarIsInitializedOp
# bn4a_branch2a/moving_mean/Assign
# bn4a_branch2a/moving_mean/Read/ReadVariableOp
# bn4a_branch2a/moving_variance/Initializer/ones
# bn4a_branch2a/moving_variance
# bn4a_branch2a/moving_variance/IsInitialized/VarIsInitializedOp
# bn4a_branch2a/moving_variance/Assign
# bn4a_branch2a/moving_variance/Read/ReadVariableOp
# bn4a_branch2a/ReadVariableOp
# bn4a_branch2a/ReadVariableOp_1
# bn4a_branch2a/FusedBatchNormV3/ReadVariableOp
# bn4a_branch2a/FusedBatchNormV3/ReadVariableOp_1
# bn4a_branch2a/FusedBatchNormV3
# activation_15/Relu
# res4a_branch2b/kernel/Initializer/random_uniform/shape
# res4a_branch2b/kernel/Initializer/random_uniform/min
# res4a_branch2b/kernel/Initializer/random_uniform/max
# res4a_branch2b/kernel/Initializer/random_uniform/RandomUniform
# res4a_branch2b/kernel/Initializer/random_uniform/sub
# res4a_branch2b/kernel/Initializer/random_uniform/mul
# res4a_branch2b/kernel/Initializer/random_uniform
# res4a_branch2b/kernel
# res4a_branch2b/kernel/IsInitialized/VarIsInitializedOp
# res4a_branch2b/kernel/Assign
# res4a_branch2b/kernel/Read/ReadVariableOp
# res4a_branch2b/bias/Initializer/zeros
# res4a_branch2b/bias
# res4a_branch2b/bias/IsInitialized/VarIsInitializedOp
# res4a_branch2b/bias/Assign
# res4a_branch2b/bias/Read/ReadVariableOp
# res4a_branch2b/Conv2D/ReadVariableOp
# res4a_branch2b/Conv2D
# res4a_branch2b/BiasAdd/ReadVariableOp
# res4a_branch2b/BiasAdd
# bn4a_branch2b/gamma/Initializer/ones
# bn4a_branch2b/gamma
# bn4a_branch2b/gamma/IsInitialized/VarIsInitializedOp
# bn4a_branch2b/gamma/Assign
# bn4a_branch2b/gamma/Read/ReadVariableOp
# bn4a_branch2b/beta/Initializer/zeros
# bn4a_branch2b/beta
# bn4a_branch2b/beta/IsInitialized/VarIsInitializedOp
# bn4a_branch2b/beta/Assign
# bn4a_branch2b/beta/Read/ReadVariableOp
# bn4a_branch2b/moving_mean/Initializer/zeros
# bn4a_branch2b/moving_mean
# bn4a_branch2b/moving_mean/IsInitialized/VarIsInitializedOp
# bn4a_branch2b/moving_mean/Assign
# bn4a_branch2b/moving_mean/Read/ReadVariableOp
# bn4a_branch2b/moving_variance/Initializer/ones
# bn4a_branch2b/moving_variance
# bn4a_branch2b/moving_variance/IsInitialized/VarIsInitializedOp
# bn4a_branch2b/moving_variance/Assign
# bn4a_branch2b/moving_variance/Read/ReadVariableOp
# bn4a_branch2b/ReadVariableOp
# bn4a_branch2b/ReadVariableOp_1
# bn4a_branch2b/FusedBatchNormV3/ReadVariableOp
# bn4a_branch2b/FusedBatchNormV3/ReadVariableOp_1
# bn4a_branch2b/FusedBatchNormV3
# activation_16/Relu
# res4a_branch2c/kernel/Initializer/random_uniform/shape
# res4a_branch2c/kernel/Initializer/random_uniform/min
# res4a_branch2c/kernel/Initializer/random_uniform/max
# res4a_branch2c/kernel/Initializer/random_uniform/RandomUniform
# ...
# TfPoseEstimator/Openpose/MConv_Stage6_L1_3_depthwise/depthwise_weights
# TfPoseEstimator/Openpose/MConv_Stage6_L1_3_pointwise/weights
# TfPoseEstimator/Openpose/MConv_Stage6_L1_3_depthwise/depthwise
# TfPoseEstimator/Openpose/MConv_Stage6_L1_3_pointwise/Conv2D
# TfPoseEstimator/Openpose/MConv_Stage6_L1_3_pointwise/Conv2D_bn_offset
# TfPoseEstimator/Openpose/MConv_Stage6_L1_3_pointwise/BatchNorm/FusedBatchNorm
# TfPoseEstimator/Openpose/MConv_Stage6_L1_3_pointwise/Relu
# TfPoseEstimator/Openpose/MConv_Stage6_L1_4_depthwise/depthwise_weights
# TfPoseEstimator/Openpose/MConv_Stage6_L1_4_pointwise/weights
# TfPoseEstimator/Openpose/MConv_Stage6_L1_4_depthwise/depthwise
# TfPoseEstimator/Openpose/MConv_Stage6_L1_4_pointwise/Conv2D
# TfPoseEstimator/Openpose/MConv_Stage6_L1_4_pointwise/Conv2D_bn_offset
# TfPoseEstimator/Openpose/MConv_Stage6_L1_4_pointwise/BatchNorm/FusedBatchNorm
# TfPoseEstimator/Openpose/MConv_Stage6_L1_4_pointwise/Relu
# TfPoseEstimator/Openpose/MConv_Stage6_L1_5_depthwise/depthwise_weights
# TfPoseEstimator/Openpose/MConv_Stage6_L1_5_pointwise/weights
# TfPoseEstimator/Openpose/MConv_Stage6_L1_5_depthwise/depthwise
# TfPoseEstimator/Openpose/MConv_Stage6_L1_5_pointwise/Conv2D
# TfPoseEstimator/Openpose/MConv_Stage6_L1_5_pointwise/Conv2D_bn_offset
# TfPoseEstimator/Openpose/MConv_Stage6_L1_5_pointwise/BatchNorm/FusedBatchNorm
# TfPoseEstimator/Openpose/MConv_Stage6_L2_1_depthwise/depthwise_weights
# TfPoseEstimator/Openpose/MConv_Stage6_L2_1_pointwise/weights
# TfPoseEstimator/Openpose/MConv_Stage6_L2_1_depthwise/depthwise
# TfPoseEstimator/Openpose/MConv_Stage6_L2_1_pointwise/Conv2D
# TfPoseEstimator/Openpose/MConv_Stage6_L2_1_pointwise/Conv2D_bn_offset
# TfPoseEstimator/Openpose/MConv_Stage6_L2_1_pointwise/BatchNorm/FusedBatchNorm
# TfPoseEstimator/Openpose/MConv_Stage6_L2_1_pointwise/Relu
# TfPoseEstimator/Openpose/MConv_Stage6_L2_2_depthwise/depthwise_weights
# TfPoseEstimator/Openpose/MConv_Stage6_L2_2_pointwise/weights
# TfPoseEstimator/Openpose/MConv_Stage6_L2_2_depthwise/depthwise
# TfPoseEstimator/Openpose/MConv_Stage6_L2_2_pointwise/Conv2D
# TfPoseEstimator/Openpose/MConv_Stage6_L2_2_pointwise/Conv2D_bn_offset
# TfPoseEstimator/Openpose/MConv_Stage6_L2_2_pointwise/BatchNorm/FusedBatchNorm
# TfPoseEstimator/Openpose/MConv_Stage6_L2_2_pointwise/Relu
# TfPoseEstimator/Openpose/MConv_Stage6_L2_3_depthwise/depthwise_weights
# TfPoseEstimator/Openpose/MConv_Stage6_L2_3_pointwise/weights
# TfPoseEstimator/Openpose/MConv_Stage6_L2_3_depthwise/depthwise
# TfPoseEstimator/Openpose/MConv_Stage6_L2_3_pointwise/Conv2D
# TfPoseEstimator/Openpose/MConv_Stage6_L2_3_pointwise/Conv2D_bn_offset
# TfPoseEstimator/Openpose/MConv_Stage6_L2_3_pointwise/BatchNorm/FusedBatchNorm
# TfPoseEstimator/Openpose/MConv_Stage6_L2_3_pointwise/Relu
# TfPoseEstimator/Openpose/MConv_Stage6_L2_4_depthwise/depthwise_weights
# TfPoseEstimator/Openpose/MConv_Stage6_L2_4_pointwise/weights
# TfPoseEstimator/Openpose/MConv_Stage6_L2_4_depthwise/depthwise
# TfPoseEstimator/Openpose/MConv_Stage6_L2_4_pointwise/Conv2D
# TfPoseEstimator/Openpose/MConv_Stage6_L2_4_pointwise/Conv2D_bn_offset
# TfPoseEstimator/Openpose/MConv_Stage6_L2_4_pointwise/BatchNorm/FusedBatchNorm
# TfPoseEstimator/Openpose/MConv_Stage6_L2_4_pointwise/Relu
# TfPoseEstimator/Openpose/MConv_Stage6_L2_5_depthwise/depthwise_weights
# TfPoseEstimator/Openpose/MConv_Stage6_L2_5_pointwise/weights
# TfPoseEstimator/Openpose/MConv_Stage6_L2_5_depthwise/depthwise
# TfPoseEstimator/Openpose/MConv_Stage6_L2_5_pointwise/Conv2D
# TfPoseEstimator/Openpose/MConv_Stage6_L2_5_pointwise/Conv2D_bn_offset
# TfPoseEstimator/Openpose/MConv_Stage6_L2_5_pointwise/BatchNorm/FusedBatchNorm
# TfPoseEstimator/Openpose/concat_stage7/axis
# TfPoseEstimator/Openpose/concat_stage7
# Traceback (most recent call last):
#   File "/Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-6802def89ffe>", line 26, in <module>
#     print(image_api.recommend_object_position(center_point, image, r['class_ids'][index] == 1))
#   File "/Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/process/image_api.py", line 99, in recommend_object_position
#     e = TfPoseEstimator(get_graph_path('mobilenet_thin'))
#   File "/Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/tf_pose/estimator.py", line 360, in __init__
#     [v for v in tf.compat.v1.global_variables() if
#   File "/Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/tf_pose/estimator.py", line 362, in <listcomp>
#     self.persistent_sess.run(tf.compat.v1.report_uninitialized_variables())]
#   File "/Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 958, in run
#     run_metadata_ptr)
#   File "/Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 1181, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 1359, in _do_run
#     run_metadata)
#   File "/Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 1365, in _do_call
#     return fn(*args)
#   File "/Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 1348, in _run_fn
#     self._extend_graph()
#   File "/Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 1388, in _extend_graph
#     tf_session.ExtendSession(self._session)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py", line 691, in getsourcefile
#     importlib.machinery.EXTENSION_SUFFIXES):
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py", line 690, in <genexpr>
#     elif any(filename.endswith(s) for s in
# KeyboardInterrupt
# 2020-08-15 22:04:11,354 WARNING From /Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_v1.py:2070: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# [2020-08-15 22:04:23,178] [TfPoseEstimator] [INFO] loading graph from /Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/models/graph/mobilenet_thin/graph_opt.pb(default size=320x240)
# 2020-08-15 22:04:23,178 INFO loading graph from /Users/dongkyoo/Develop/GomsonModel/aktwelve_mask_rcnn/models/graph/mobilenet_thin/graph_opt.pb(default size=320x240)
# 2020-08-15 22:04:33,980 ERROR Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# 2020-08-15 22:04:34,021 INFO
# Unfortunately, your original traceback can not be constructed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-5-6802def89ffe> in <module>
#      25         all_layered_image = cv2.circle(all_layered_image, center_point, 5, 1, 2)
# ---> 26         print(image_api.recommend_object_position(center_point, image, r['class_ids'][index] == 1))
#      27
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/process/image_api.py in recommend_object_position(center_point, image, is_person)
#      98     if is_person:
# ---> 99         e = TfPoseEstimator(get_graph_path('mobilenet_thin'))
#     100         humans = e.inference(image)
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/tf_pose/estimator.py in __init__(self, graph_path, target_size, tf_config, trt_bool)
#     359         self.persistent_sess.run(tf.compat.v1.variables_initializer(
# --> 360             [v for v in tf.compat.v1.global_variables() if
#     361              v.name.split(':')[0] in [x.decode('utf-8') for x in
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/tf_pose/estimator.py in <listcomp>(.0)
#     361              v.name.split(':')[0] in [x.decode('utf-8') for x in
# --> 362                                       self.persistent_sess.run(tf.compat.v1.report_uninitialized_variables())]
#     363              ])
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     957       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 958                          run_metadata_ptr)
#     959       if run_metadata:
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1180       results = self._do_run(handle, final_targets, final_fetches,
# -> 1181                              feed_dict_tensor, options, run_metadata)
#    1182     else:
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1347       # Ensure any changes to the graph are reflected in the runtime.
# -> 1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1387     with self._graph._session_run_lock():  # pylint: disable=protected-access
# -> 1388       tf_session.ExtendSession(self._session)
#    1389
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     except Exception:
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#    2049                     self._showtraceback(etype, value, stb)
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434             self.tb = tb
#    1435         return FormattedTB.structured_traceback(
# -> 1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#    1438
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334             # Verbose modes need a full traceback
#    1335             return VerboseTB.structured_traceback(
# -> 1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#    1338         elif mode == 'Minimal':
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191
#    1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1193                                                                tb_offset)
#    1194
#    1195         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/Develop/GomsonModel/aktwelve_mask_rcnn/venv/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
